# %%
pip install ibapi
# Out:
# Requirement already satisfied: ibapi in /opt/anaconda3/lib/python3.8/site-packages (9.81.1.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ibapi.contract import Contract

# %%
 from decimal import *

# %%
from ibapi.client import *
from ibapi.wrapper import *
 
class TestApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self)
 
    def nextValidId(self, orderId: OrderId):
         
        mycontract = Contract()
        mycontract.symbol = "FIGS"
        mycontract.secType = "STK"   
        mycontract.exchange = "SMART"
        mycontract.currency = "USD"
 
        self.reqContractDetails(orderId, mycontract)
         
    def contractDetails(self, reqId: int, contractDetails: ContractDetails):
        print(contractDetails.contract)
 
        myorder = Order()
        myorder.orderId = reqId
        myorder.action = "BUY"
        myorder.tif = "GTC"
        myorder.orderType = "MKT"
        myorder.totalQuantity = 5163
 
        self.placeOrder(myorder.orderId, contractDetails.contract, myorder)
 
 
    def openOrder(self, orderId: OrderId, contract: Contract, order: Order, orderState: OrderState):
        print(f"openOrder. orderId: {orderId}, contract: {contract}, order: {order}")
 
    def orderStatus(self, orderId: OrderId, status: str, filled: Decimal, remaining: Decimal, avgFillPrice: float, permId: int, parentId: int, lastFillPrice: float, clientId: int, whyHeld: str, mktCapPrice: float):
        print(f"orderId: {orderId}, status: {status}, filled: {filled}, remaining: {remaining}, avgFillPrice: {avgFillPrice}, permId: {permId}, parentId: {parentId}, lastFillPrice: {lastFillPrice}, clientId: {clientId}, whyHeld: {whyHeld}, mktCapPrice: {mktCapPrice}")
 
    def execDetails(self, reqId: int, contract: Contract, execution: Execution):
        print(f"reqId: {reqId}, contract: {contract}, execution: {execution}")
 
 
app = TestApp()
app.connect("127.0.0.1", 7497, 100)
app.run()
app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# 493581450,FIGS,STK,,0,,,SMART,NYSE,USD,FIGS,FIGS,False,,,,combo:
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 0, remaining: 5163, avgFillPrice: 0.0, permId: 722643677, parentId: 0, lastFillPrice: 0.0, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,EDGEA,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bad.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: EDGEA, Side: BOT, Shares: 100, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 100, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 100, remaining: 5063, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,IEX,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bae.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: IEX, Side: BOT, Shares: 505, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 605, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 605, remaining: 4558, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,NYSENAT,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26baf.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: NYSENAT, Side: BOT, Shares: 100, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 705, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 705, remaining: 4458, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,ISLAND,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb0.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: ISLAND, Side: BOT, Shares: 1100, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 1805, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 1805, remaining: 3358, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,ARCA,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb1.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: ARCA, Side: BOT, Shares: 500, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 2305, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 2305, remaining: 2858, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,NYSE,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb2.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: NYSE, Side: BOT, Shares: 900, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 3205, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 3205, remaining: 1958, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,DRCTEDGE,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb3.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: DRCTEDGE, Side: BOT, Shares: 100, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 3305, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 3305, remaining: 1858, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,BATS,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb4.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: BATS, Side: BOT, Shares: 100, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 3405, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 3405, remaining: 1758, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,MEMX,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb5.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: MEMX, Side: BOT, Shares: 14, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 3419, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@9.37 GTC
# orderId: 2, status: PreSubmitted, filled: 3419, remaining: 1744, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3419, remaining: 1744, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3419, remaining: 1744, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3419, remaining: 1744, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3419, remaining: 1744, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3419, remaining: 1744, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,IEX,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb6.01.01, Time: 20230207 14:51:55 US/Eastern, Account: DU6730172, Exchange: IEX, Side: BOT, Shares: 505, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 3924, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 3924, remaining: 1239, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,IEX,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb8.01.01, Time: 20230207 14:51:57 US/Eastern, Account: DU6730172, Exchange: IEX, Side: BOT, Shares: 505, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 4429, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 4429, remaining: 734, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,NYSE,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bb9.01.01, Time: 20230207 14:51:57 US/Eastern, Account: DU6730172, Exchange: NYSE, Side: BOT, Shares: 154, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 4583, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 4583, remaining: 580, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 4583, remaining: 580, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 4583, remaining: 580, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 4583, remaining: 580, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,IEX,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bba.01.01, Time: 20230207 14:51:57 US/Eastern, Account: DU6730172, Exchange: IEX, Side: BOT, Shares: 505, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 5088, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 5088, remaining: 75, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 5088, remaining: 75, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Submitted, filled: 5088, remaining: 75, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 493581450,FIGS,STK,,0,,,ISLAND,,USD,FIGS,FIGS,False,,,,combo:, execution: ExecId: 00025b44.63e26bbf.01.01, Time: 20230207 14:51:58 US/Eastern, Account: DU6730172, Exchange: ISLAND, Side: BOT, Shares: 75, Price: 9.37, PermId: 722643677, ClientId: 100, OrderId: 2, Liquidation: 0, CumQty: 5163, AvgPrice: 9.37, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Filled, filled: 5163, remaining: 0, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 2, contract: 493581450,FIGS,STK,,0,?,,SMART,,USD,FIGS,FIGS,False,,,,combo:, order: 2,100,722643677: MKT BUY 5163@0 GTC
# orderId: 2, status: Filled, filled: 5163, remaining: 0, avgFillPrice: 9.37, permId: 722643677, parentId: 0, lastFillPrice: 9.37, clientId: 100, whyHeld: , mktCapPrice: 0.0

# %%
from ibapi.client import *
from ibapi.wrapper import *
 
class TestApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self)
 
    def nextValidId(self, orderId: OrderId):
         
        mycontract = Contract()
        mycontract.symbol = "CVX"
        mycontract.secType = "STK"   
        mycontract.exchange = "SMART"
        mycontract.currency = "USD"
 
        self.reqContractDetails(orderId, mycontract)
         
    def contractDetails(self, reqId: int, contractDetails: ContractDetails):
        print(contractDetails.contract)
 
        myorder = Order()
        myorder.orderId = reqId
        myorder.action = "SELL"
        myorder.tif = "GTC"
        myorder.orderType = "MKT"
        myorder.totalQuantity = 290
 
        self.placeOrder(myorder.orderId, contractDetails.contract, myorder)
 
 
    def openOrder(self, orderId: OrderId, contract: Contract, order: Order, orderState: OrderState):
        print(f"openOrder. orderId: {orderId}, contract: {contract}, order: {order}")
 
    def orderStatus(self, orderId: OrderId, status: str, filled: Decimal, remaining: Decimal, avgFillPrice: float, permId: int, parentId: int, lastFillPrice: float, clientId: int, whyHeld: str, mktCapPrice: float):
        print(f"orderId: {orderId}, status: {status}, filled: {filled}, remaining: {remaining}, avgFillPrice: {avgFillPrice}, permId: {permId}, parentId: {parentId}, lastFillPrice: {lastFillPrice}, clientId: {clientId}, whyHeld: {whyHeld}, mktCapPrice: {mktCapPrice}")
 
    def execDetails(self, reqId: int, contract: Contract, execution: Execution):
        print(f"reqId: {reqId}, contract: {contract}, execution: {execution}")
 
 
app = TestApp()
app.connect("127.0.0.1", 7497, 100)
app.run()
app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# 5684,CVX,STK,,0,,,SMART,NYSE,USD,CVX,CVX,False,,,,combo:
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: PreSubmitted, filled: 0, remaining: 290, avgFillPrice: 0.0, permId: 722643678, parentId: 0, lastFillPrice: 0.0, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 5684,CVX,STK,,0,,,NYSE,,USD,CVX,CVX,False,,,,combo:, execution: ExecId: 00025b44.63e26be2.01.01, Time: 20230207 14:52:57 US/Eastern, Account: DU6730172, Exchange: NYSE, Side: SLD, Shares: 200, Price: 173.47, PermId: 722643678, ClientId: 100, OrderId: 3, Liquidation: 0, CumQty: 200, AvgPrice: 173.47, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: PreSubmitted, filled: 200, remaining: 90, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 5684,CVX,STK,,0,,,MEMX,,USD,CVX,CVX,False,,,,combo:, execution: ExecId: 00025b44.63e26be3.01.01, Time: 20230207 14:52:57 US/Eastern, Account: DU6730172, Exchange: MEMX, Side: SLD, Shares: 1, Price: 173.47, PermId: 722643678, ClientId: 100, OrderId: 3, Liquidation: 0, CumQty: 201, AvgPrice: 173.47, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: PreSubmitted, filled: 201, remaining: 89, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: Submitted, filled: 201, remaining: 89, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: Submitted, filled: 201, remaining: 89, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: Submitted, filled: 201, remaining: 89, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# reqId: -1, contract: 5684,CVX,STK,,0,,,BATS,,USD,CVX,CVX,False,,,,combo:, execution: ExecId: 00025b44.63e26be4.01.01, Time: 20230207 14:52:57 US/Eastern, Account: DU6730172, Exchange: BATS, Side: SLD, Shares: 89, Price: 173.47, PermId: 722643678, ClientId: 100, OrderId: 3, Liquidation: 0, CumQty: 290, AvgPrice: 173.47, OrderRef: , EvRule: , EvMultiplier: 0, ModelCode: , LastLiquidity: 2
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: Filled, filled: 290, remaining: 0, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# openOrder. orderId: 3, contract: 5684,CVX,STK,,0,?,,SMART,,USD,CVX,CVX,False,,,,combo:, order: 3,100,722643678: MKT SELL 290@0 GTC
# orderId: 3, status: Filled, filled: 290, remaining: 0, avgFillPrice: 173.47, permId: 722643678, parentId: 0, lastFillPrice: 173.47, clientId: 100, whyHeld: , mktCapPrice: 0.0
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; fundfarm; ushmds; secdefil. The following farms are not connected: hfarm; euhmds.
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds. The following farms are not connected: hfarm; secdefil.
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil. The following farms are not connected: cashfarm.
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; usfarm; euhmds; fundfarm; ushmds; secdefil. The following farms are not connected: eufarmnj.
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil. The following farms are not connected: hfarm; jfarm.
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2105 HMDS data farm connection is broken:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: secdefil. The following farms are not connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds.
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; secdefil. The following farms are not connected: hfarm; euhmds; fundfarm; ushmds.
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; usfuture; cashfarm; eufarmnj; usfarm; ushmds. The following farms are not connected: hfarm; jfarm; euhmds; fundfarm; secdefil.
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: hfarm; jfarm; euhmds; fundfarm.
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: euhmds; fundfarm.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: usfarm.nj; usfuture; cashfarm; eufarmnj; usfarm; ushmds; secdefil. The following farms are not connected: hfarm; jfarm; euhmds; fundfarm.
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; ushmds. The following farms are not connected: euhmds; fundfarm; secdefil.
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds; secdefil.
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: secdefil. The following farms are not connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds.
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 1100 Connectivity between IB and Trader Workstation has been lost.
# ERROR -1 2157 Sec-def data farm connection is broken:secdefil
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR -1 1102 Connectivity between IB and Trader Workstation has been restored - data maintained. The following farms are connected: secdefil. The following farms are not connected: hfarm; usfarm.nj; jfarm; usfuture; cashfarm; eufarmnj; usfarm; euhmds; fundfarm; ushmds.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2108 Market data farm connection is inactive but should be available upon demand.usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:hfarm
# ERROR -1 2108 Market data farm connection is inactive but should be available upon demand.hfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2108 Market data farm connection is inactive but should be available upon demand.jfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:eufarmnj
# ERROR -1 2108 Market data farm connection is inactive but should be available upon demand.eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2104 Market data farm connection is OK:cashfarm
